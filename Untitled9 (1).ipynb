# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
#2
time_spent = np.random.uniform(0, 10, 200)
logits = -3 + 0.7 * time_spent
prob = 1 / (1 + np.exp(-logits))
purchase = np.random.binomial(1, prob)

X = time_spent.reshape(-1,1)
y = purchase

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = LogisticRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("Accuracy: ",accuracy_score(y_test, y_pred))
print("confusion matrix: ",confusion_matrix(y_test, y_pred))
print("classification report: ",classification_report(y_test, y_pred))

plt.scatter(X, y, c=purchase, cmap='coolwarm', label='data')
plt.plot(np.sort(time_spent), model.predict_proba(np.sort(time_spent).reshape(-1,1))[:,1], color='black', label='sigmoid line')
plt.legend()
plt.show()
# Out:
# Accuracy:  0.7833333333333333
# confusion matrix:  [[12 10]
#  [ 3 35]]
# classification report:                precision    recall  f1-score   support
#
#            0       0.80      0.55      0.65        22
#            1       0.78      0.92      0.84        38
#
#     accuracy                           0.78        60
#    macro avg       0.79      0.73      0.75        60
# weighted avg       0.79      0.78      0.77        60

# %%
#3
calories = np.random.uniform(1500, 4000, 200)
z = -12 + 0.004 * calories
prob = 1 / (1 + np.exp(-z))
overweight = np.random.binomial(1,prob)

x = calories.reshape(-1,1)
y = overweight

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

model = LogisticRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
print("Accuracy: ",accuracy_score(y_test, y_pred))
print("confusion matrix: ",confusion_matrix(y_test, y_pred))
print("classification report: ",classification_report(y_test, y_pred))

plt.scatter(calories, overweight, c=overweight, cmap='coolwarm', label='data')
plt.plot(np.sort(calories),model.predict_proba(np.sort(calories).reshape(-1,1))[:,1], color='black', label="Sigmoid Line")
plt.legend()
plt.show()
# Out:
# Accuracy:  0.8666666666666667
# confusion matrix:  [[30  5]
#  [ 3 22]]
# classification report:                precision    recall  f1-score   support
#
#            0       0.91      0.86      0.88        35
#            1       0.81      0.88      0.85        25
#
#     accuracy                           0.87        60
#    macro avg       0.86      0.87      0.86        60
# weighted avg       0.87      0.87      0.87        60

# %%
#4
score = np.random.uniform(300, 850, 200)
z = 10 - 0.02 * score
prob = 1 / (1 + np.exp(-z))
bank_loan = np.random.binomial(1, prob)

x = score.reshape(-1,1)
y = bank_loan

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

model = LogisticRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
print("Accuracy Score: ",accuracy_score(y_test,y_pred))
print("confusion matrix: ",confusion_matrix(y_test, y_pred))
print("classification report: ",classification_report(y_test, y_pred))

plt.scatter(score, bank_loan, c=bank_loan, cmap='coolwarm', label='data')
plt.plot(np.sort(score), model.predict_proba(np.sort(score).reshape(-1,1))[:,1], color='black', label='sigmoid line')
plt.legend()
plt.show()
# Out:
# Accuracy Score:  0.8666666666666667
# confusion matrix:  [[36  2]
#  [ 6 16]]
# classification report:                precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90        38
#            1       0.89      0.73      0.80        22
#
#     accuracy                           0.87        60
#    macro avg       0.87      0.84      0.85        60
# weighted avg       0.87      0.87      0.86        60

# %%
#7
speed = np.random.uniform(20, 120, 200)
logits = -10 + 0.1 * speed
prob = 1 / (1 + np.exp(-logits))
accident = np.random.binomial(1, prob)

x = speed.reshape(-1,1)
y = accident

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
model = LogisticRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
print("Accuracy: ",accuracy_score(y_test, y_pred))
print("confusion matrix: ",confusion_matrix(y_test, y_pred))
print("classification report: ",classification_report(y_test, y_pred))

plt.scatter(speed, accident, c=accident, cmap='coolwarm', label='data')
plt.plot(np.sort(speed), model.predict_proba(np.sort(speed).reshape(-1,1))[:,1], color='black', label='sigmoid line')
plt.legend()
plt.show()
# Out:
# Accuracy:  0.8833333333333333
# confusion matrix:  [[47  4]
#  [ 3  6]]
# classification report:                precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93        51
#            1       0.60      0.67      0.63         9
#
#     accuracy                           0.88        60
#    macro avg       0.77      0.79      0.78        60
# weighted avg       0.89      0.88      0.89        60

# %%
#8
titanic = sns.load_dataset('titanic')
data = titanic[['age','survived']].dropna()
x = data[['age']]
y = data['survived']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=4)

model = LogisticRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
print("Accuracy: ",accuracy_score(y_test, y_pred))
print("confusion matrix: ",confusion_matrix(y_test, y_pred))
print("classification report: ",classification_report(y_test, y_pred))

plt.scatter(data['age'], data['survived'], c=data['survived'], cmap='coolwarm', label='data')
plt.plot(np.sort(data['age']), model.predict_proba(np.sort(data['age']).reshape(-1,1))[:,1], color='black', label='sigmoid line')
plt.legend()
plt.show()
# Out:
# Accuracy:  0.5767441860465117
# confusion matrix:  [[124   0]
#  [ 91   0]]
# classification report:                precision    recall  f1-score   support
#
#            0       0.58      1.00      0.73       124
#            1       0.00      0.00      0.00        91
#
#     accuracy                           0.58       215
#    macro avg       0.29      0.50      0.37       215
# weighted avg       0.33      0.58      0.42       215
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
# titanic = sns.load_dataset('titanic')

X = titanic[['age','fare']].dropna()
y = titanic.loc[x.index, 'survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

plt.figure(figsize=(8,6))
sns.scatterplot(x='age', y='fare', hue=y, data=x, palette='coolwarm')
plt.legend(title='survived')
plt.show()
# Out:
# Accuracy: 0.641860465116279
# [[114  12]
#  [ 65  24]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.90      0.75       126
#            1       0.67      0.27      0.38        89
#
#     accuracy                           0.64       215
#    macro avg       0.65      0.59      0.57       215
# weighted avg       0.65      0.64      0.60       215

# %%
titanic = sns.load_dataset('titanic')
titanic['sex'] = titanic['sex'].map({'male':0, 'female':1})

# Correct: use X, not x
X = titanic[['sex','pclass']].dropna()
y = titanic.loc[X.index, 'survived']      # FIXED

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# Logistic Regression Model
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# Correct plot
plt.figure(figsize=(8,6))
sns.barplot(x='pclass', y='survived', hue='sex', data=titanic, palette='coolwarm',ci=None)
plt.legend(title='sex', labels=['male','female'])
plt.show()
# Out:
# Accuracy: 0.7910447761194029
# [[134  23]
#  [ 33  78]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.83       157
#            1       0.77      0.70      0.74       111
#
#     accuracy                           0.79       268
#    macro avg       0.79      0.78      0.78       268
# weighted avg       0.79      0.79      0.79       268
# /tmp/ipython-input-1341939774.py:25: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='pclass', y='survived', hue='sex', data=titanic, palette='coolwarm',ci=None)

# %%
titanic = sns.load_dataset('titanic')
titanic['sex'] = titanic['sex'].map({'male':0, 'female':1})

# Correct: use X, not x
X = titanic[['age','sex','pclass']].dropna()
y = titanic.loc[X.index, 'survived']      # FIXED

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# Logistic Regression Model
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# Correct plot
plt.hist(model.predict_proba(X)[:,1], bins=20)
plt.show()
# Out:
# Accuracy: 0.7627906976744186
# [[102  24]
#  [ 27  62]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80       126
#            1       0.72      0.70      0.71        89
#
#     accuracy                           0.76       215
#    macro avg       0.76      0.75      0.75       215
# weighted avg       0.76      0.76      0.76       215

# %%
titanic = sns.load_dataset('titanic')
titanic['sex'] = titanic['sex'].map({'male':0,'female':1})
x = titanic[['pclass','sex','age','sibsp','parch','fare']].dropna()
y = titanic.loc[x.index, 'survived']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
model = LogisticRegression(max_iter=200)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
print("Accuracy: ",accuracy_score(y_test, y_pred))
print("confusion matrix: ",confusion_matrix(y_test, y_pred))
print("classification report: ",classification_report(y_test, y_pred))

plt.hist(model.predict_proba(x)[:,1], bins=20, edgecolor='black', color='skyblue')
plt.show()
# Out:
# Accuracy:  0.772093023255814
# confusion matrix:  [[107  19]
#  [ 30  59]]
# classification report:                precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81       126
#            1       0.76      0.66      0.71        89
#
#     accuracy                           0.77       215
#    macro avg       0.77      0.76      0.76       215
# weighted avg       0.77      0.77      0.77       215
